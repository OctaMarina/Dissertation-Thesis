# %%
import pandas as pd
import numpy as np

# %%
df_time = pd.read_csv('btcusd_1-min_data.csv')
df_volume = pd.read_csv('btc_dataset_volume_1_hour.csv')

# %%
df_time.shape
# Out:
# (7409921, 6)

# %%
df_volume.shape
# Out:
# (157080, 10)

# %%
df_time.shape[0] - df_volume.shape[0]
# Out:
# 7252841

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       5 from pipeline import make_sequences, chronological_split, flatten_3d_to_2d, predict_proba_model, Config
#       7 # --- 1. RECALCULĂM VARIABILELE LIPSĂ (Pentru a rula independent) ---
#       8 # Extragem strategia din TAG și configurăm corect coloana de label
# ----> 9 strategy = TAG.split("_")[1]
#      10 y_col = "y_long" if strategy == "long" else "y_short"
#      12 # Reconstruim Config-ul și datele brute
#
# NameError: name 'TAG' is not defined
